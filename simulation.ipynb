# %% [markdown]
# # Simulation for MSCI 333 Project
# By: Justin Du, Michael Sheng

# %%
# !pip install simpy

import simpy
import random
import numpy as np

class SFGHSimulation:
    def __init__(self, env):
        self.env = env
        self.ambulance_queue = simpy.Resource(env, capacity=1)
        self.walk_in_queue = simpy.Resource(env, capacity=1)
        self.waiting_room = simpy.Resource(env, capacity=100)       #Combined waiting room for Non-Urgent and Referred
        self.resuscitation_zone = simpy.Resource(env, capacity=1)   # Resuscitation zone with a capacity of 1 patient
        self.zone_1R = simpy.Resource(env, capacity=8)              # Zone 1R which is exclusive for resuscitation patients has a capacity of 8 patients
        self.zone_1 = simpy.Resource(env, capacity=18)              # Zone 1 with a capacity of 18 patients
        self.zone_2 = simpy.Resource(env, capacity=8)               # Zone 2 with a capacity of 8 patients
        self.zone_3 = simpy.Resource(env, capacity=12)              # Zone 3 with a capacity of 12 patients
        self.zone_4 = simpy.Resource(env, capacity=12)              # Zone 4 with a capacity of 12 patients
        self.patients_in_waiting_room = 0
        self.critical_care_diversion = False

    def patient_arrival(self):
        return random.uniform[0,1] <= np.random.poisson(1/12)

    #arriving by ambulance
    def arrival_type_ambulance(self, patient):
        trauma_probability = 0.5
        is_trauma = random.uniform(0, 1) < trauma_probability

        with self.ambulance_queue.request() as request:
            yield request
            print(f"Patient {patient} arrived by ambulance at time {self.env.now}.")

            #trauma patients assumed to be traige level resuscitation
            if is_trauma:
                print(f"Patient {patient} is a traum patient, cannot be diverted.")
                with self.zone_1R.request() as zone_request: #request methods requests a capacity spot, keeps track of zone capacity behind the scenes
                    try:
                        yield zone_request
                        print(f"Patient {patient} moved to Zone 1R at time {self.env.now}.")
                        time_spent_zone_1R = random.uniform(35, 180)
                        yield self.env.timeout(time_spent_zone_1R)
                        print(f"Patient {patient} spent {time_spent_zone_1R} minutes in Zone 1R.")


                        # when admitted they exit our system so they are also discharged
                        discharge_time = self.env.now
                        print(f"Patient {patient} discharged at time {discharge_time}.")

                    except simpy.Interrupt:
                        print(f"Critical Care Diversion: Patient {patient} since all resuscitation beds are full.")
                        self.critical_care_diversion = True
                        return

            #patients are not trauma patients, can be triage level 2-5
            else:
                print(f"Patient {patient} categorized as Non-Trauma.")

                trauma_catgories = ["Emergency", "Resuscitation", "Urgent", "Non-Urgent"]

                non_trauma_label = random.choices(trauma_catgories, weights = [20, 35, 30, 15])


                if non_trauma_label == "Emergency":
                    print(f"Patient {patient} labelled as Emergency.")
                    triage_duration_emergency = random.uniform(1, 2)
                    yield self.env.timeout(triage_duration_emergency)

                    with self.zone_1.request() as zone_request:
                        try:
                            yield zone_request
                            print(f"Patient {patient} moved to Zone 1 at time {self.env.now}.")
                            zone_1_time = random.uniform(35, 180)
                            yield self.env.timeout(zone_1_time)
                            print(f"Patient {patient} spent {zone_1_time} minutes in Zone 1.")

                            discharge_time = self.env.now
                            print(f"Patient {patient} discharged at time {discharge_time}.")

                        except simpy.Interrupt:
                            self.redirect_between_zones(patient, self.zone_1, self.zone_2)

                elif non_trauma_label == "Resuscitation":
                    print(f"Patient {patient} labelled as Resuscitation.")
                    triage_duration_resuscitation = random.uniform(1, 2)
                    yield self.env.timeout(triage_duration_resuscitation)

                    with self.resuscitation_zone.request() as resuscitation_request:
                        try:
                            yield resuscitation_request
                            print(f"Patient {patient} moved to Resuscitation at time {self.env.now}.")

                            resuscitation_zone_time = random.uniform(35, 180)
                            yield self.env.timeout(resuscitation_zone_time)
                            print(f"Patient {patient} spent {resuscitation_zone_time} minutes in Resuscitation.")

                            # Discharge
                            discharge_time = self.env.now
                            print(f"Patient {patient} discharged at time {discharge_time}.")

                        except simpy.Interrupt:
                            self.redirect_between_zones(patient, self.resuscitation_zone, self.zone_1)

                elif non_trauma_label == "Urgent":
                    print(f"Patient {patient} labelled as Urgent.")
                    triage_duration_urgent = random.uniform(1, 2)
                    yield self.env.timeout(triage_duration_urgent)

                    #50% chance to send patient to Zone 1
                    if random.uniform(0, 1) < 0.5:
                        with self.zone_1.request() as zone_request:
                            try:
                                yield zone_request
                                print(f"Patient {patient} moved to Zone 1 at time {self.env.now}.")

                                zone_1_workup_time = random.uniform(35, 180)
                                yield self.env.timeout(zone_1_workup_time)
                                print(f"Patient {patient} spent {zone_1_workup_time} minutes in Zone 1.")

                                #patient is admitted after work up in zone 1 so they leave our system
                                discharge_time = self.env.now
                                print(f"Patient {patient} discharged at time {discharge_time}.")

                            # if zone 1 is full then redirect
                            except simpy.Interrupt:
                                self.redirect_between_zones(patient, self.zone_1, self.zone_2)

                    else:
                        # 50% chance to send patient to Zone 2
                        with self.zone_2.request() as zone_request:
                            try:
                                yield zone_request
                                print(f"Patient {patient} moved to Zone 2 at time {self.env.now}.")

                                zone_2_workup_time = random.uniform(35, 180)
                                yield self.env.timeout(zone_2_workup_time)
                                print(f"Patient {patient} spent {zone_2_workup_time} minutes in Zone 2.")

                                discharge_time = self.env.now
                                print(f"Patient {patient} discharged at time {discharge_time}.")

                            except simpy.Interrupt:
                                self.redirect_between_zones(patient, self.zone_2, self.zone_1)

                else:  # Non-Urgent
                    print(f"Patient {patient} labelled as Non-Urgent.")
                    triage_duration_nonurgent = random.uniform(10, 15)
                    yield self.env.timeout(triage_duration_nonurgent)

                    with self.waiting_room.request() as wait_request:
                        yield wait_request
                        self.patients_in_waiting_room += 1
                        print(f"Patient {patient} moved to Waiting Room at time {self.env.now}. "
                              f"Number of people in the waiting room: {self.patients_in_waiting_room}")

                    # Remaining logic for Zone 3 and Zone 4 is unchanged

            assigned_time = self.env.now
            print(f"Patient {patient} assigned category at time {assigned_time}")

    #redirect non resuscitation patients between zones 1 and 2
    def redirect_between_zones(self, patient, zone_from, zone_to):
        with zone_to.request() as zone_request:
            try:
                yield zone_request
                print(f"Patient {patient} moved to {zone_to.name} from {zone_from.name} at time {self.env.now}.")
                zone_1_2_workup_time = random.uniform(35, 180)
                yield self.env.timeout(zone_time)
                print(f"Patient {patient} spent {zone_1_2_workup_time} minutes in {zone_to.name}.")

                discharge_time = self.env.now
                print(f"Patient {patient} discharged at time {discharge_time}.")

            except simpy.Interrupt:
                print(f"Patient {patient} redirected due to {zone_to.name} being full.")
                return

    def arrival_type_walk_in(self, patient):
        arrival_time = self.env.now
        triage_categories = ["Urgent", "Non-Urgent", "Referred"]

        triage_level = random.choices(triage_categories, weights = [33, 43, 23])


        with self.walk_in_queue.request() as request:
            yield request
            time_taken = 0  # Placeholder for time taken based on the category

            if triage_level == "Urgent":
                triage_duration = random.uniform(1, 2)  # Urgent process time between 1 and 2 minutes
                yield self.env.timeout(triage_duration)

                #50% chance in sending patient to zone 3
                if random.uniform(0, 1) < 0.5:
                    with self.zone_3.request() as zone_request:
                        try:
                            yield zone_request
                            print(f"Patient {patient} moved to Zone 3 at time {self.env.now}.")
                            zone_3_workup_time = random.uniform(35, 180)
                            yield self.env.timeout(zone_3_workup_time)
                            print(f"Patient {patient} spent {zone_3_workup_time} minutes in Zone 3.")

                            discharge_time = self.env.now
                            print(f"Patient {patient} discharged at time {discharge_time}.")

                        except simpy.Interrupt:
                            print(f"Patient {patient} redirected due to Zone 3 being full.")
                            return

                else:
                    #50% chance in sending patient to zone 3
                    with self.zone_4.request() as zone_request:
                        try:
                            yield zone_request
                            print(f"Patient {patient} moved to Zone 4 at time {self.env.now}.")
                            zone_4_workup_time = random.uniform(35, 180)
                            yield self.env.timeout(zone_4_workup_time)
                            print(f"Patient {patient} spent {zone_4_workup_time} minutes in Zone 4.")

                            discharge_time = self.env.now
                            print(f"Patient {patient} discharged at time {discharge_time}.")

                        except simpy.Interrupt:
                            print(f"Patient {patient} redirected due to Zone 4 being full.")
                            return

            else:
                #patient has treiage level non-urgent or referred
                triage_duration = random.uniform(10, 15)  #process time between 10 and 15 minutes

                yield self.env.timeout(triage_duration)
                with self.waiting_room.request() as wait_request:
                    yield wait_request
                    self.patients_in_waiting_room += 1
                    print(f"Patient {patient} moved to Waiting Room at time {self.env.now}. "
                          f"Number of people in the waiting room: {self.patients_in_waiting_room}")

                    #50% chance in sending patient to Zone 3
                    if random.uniform(0, 1) < 0.5:
                        yield self.env.timeout(0)  #patient is moved our fgrom waiting room
                        with self.zone_3.request() as zone_request:
                            try:
                                yield zone_request
                                self.patients_in_waiting_room -= 1
                                print(f"Patient {patient} moved to Zone 3 at time {self.env.now}. "
                                      f"Number of people in the waiting room: {self.patients_in_waiting_room}")

                                zone_3_workup_time = random.uniform(20, 90)
                                yield self.env.timeout(zone_3_workup_time)
                                print(f"Patient {patient} spent {zone_3_workup_time} minutes in Zone 3.")

                                discharge_time = self.env.now
                                print(f"Patient {patient} discharged at time {discharge_time}.")

                            except simpy.Interrupt:
                                print(f"Patient {patient} redirected due to Zone 3 being full.")
                                return
                    else:
                        # 50% chance to send patient to Zone 4
                        yield self.env.timeout(0)  ##patient is moved our from waiting room
                        with self.zone_4.request() as zone_request:
                            try:
                                yield zone_request
                                self.patients_in_waiting_room -= 1
                                print(f"Patient {patient} moved to Zone 4 at time {self.env.now}. "
                                      f"Number of people in the waiting room: {self.patients_in_waiting_room}")

                                zone_4_workup_time = random.uniform(20, 90)
                                yield self.env.timeout(zone_4_workup_time)
                                print(f"Patient {patient} spent {zone_4_workup_time} minutes in Zone 4.")

                                discharge_time = self.env.now
                                print(f"Patient {patient} discharged at time {discharge_time}.")

                            except simpy.Interrupt:
                                print(f"Patient {patient} redirected due to Zone 4 being full.")
                                return

            assigned_time = arrival_time + time_taken
            print(f"Patient {patient} arrived as walk-in ({triage_level}) at time {arrival_time}")
            print(f"Patient {patient} assigned category at time {assigned_time}")

def patient_generator(env, ed):
    patient_count = 1
    while env.now < 24 * 60:  # Continue generating patients until 24 hours
        if ed.patient_arrival:
          if not ed.critical_care_diversion:
              #assumed 75% chance of walk in
              if random.uniform(0, 1) < 0.75:
                  env.process(ed.arrival_type_walk_in(patient_count))
              else:
                  #assumed 25% chance of ambulance
                  env.process(ed.arrival_type_ambulance(patient_count))
              patient_count += 1
          yield env.timeout(1)


def run_simulation():
    env = simpy.Environment()
    emergency_department = SFGHSimulation(env)
    env.process(patient_generator(env, emergency_department))

    total_simulation_time = 24*60*7
    env.run(until=total_simulation_time)  #Run the simulation for 1 full week


if __name__ == "__main__":
    run_simulation()
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.1.1)
# Patient 2 arrived by ambulance at time 1.
# Patient 2 is a traum patient, cannot be diverted.
# Patient 2 moved to Zone 1R at time 1.
# Patient 1 moved to Waiting Room at time 13.46085378446452. Number of people in the waiting room: 1
# Patient 1 moved to Zone 4 at time 13.46085378446452. Number of people in the waiting room: 0
# Patient 1 spent 20.30149003416863 minutes in Zone 4.
# Patient 1 discharged at time 33.76234381863315.
# Patient 1 arrived as walk-in (['Referred']) at time 0
# Patient 1 assigned category at time 0
# Patient 4 moved to Waiting Room at time 48.10764118274322. Number of people in the waiting room: 1
# Patient 4 moved to Zone 4 at time 48.10764118274322. Number of people in the waiting room: 0
# Patient 2 spent 92.76573017300828 minutes in Zone 1R.
# Patient 2 discharged at time 93.76573017300828.
# Patient 2 assigned category at time 93.76573017300828
# Patient 3 arrived by ambulance at time 93.76573017300828.
# Patient 3 categorized as Non-Trauma.
# Patient 3 labelled as Non-Urgent.
# Patient 4 spent 53.318042472785834 minutes in Zone 4.
# Patient 4 discharged at time 101.42568365552906.
# Patient 4 arrived as walk-in (['Non-Urgent']) at time 3
# Patient 4 assigned category at time 3
# Patient 3 moved to Waiting Room at time 106.97641035400903. Number of people in the waiting room: 1
# Patient 3 assigned category at time 106.97641035400903
# Patient 6 arrived by ambulance at time 106.97641035400903.
# Patient 6 categorized as Non-Trauma.
# Patient 6 labelled as Non-Urgent.
# Patient 5 moved to Waiting Room at time 113.7280577794755. Number of people in the waiting room: 2
# Patient 5 moved to Zone 4 at time 113.7280577794755. Number of people in the waiting room: 1
# Patient 6 moved to Waiting Room at time 121.23581990927977. Number of people in the waiting room: 2
# Patient 6 assigned category at time 121.23581990927977
# Patient 10 arrived by ambulance at time 121.23581990927977.
# Patient 10 is a traum patient, cannot be diverted.
# Patient 10 moved to Zone 1R at time 121.23581990927977.
# Patient 10 spent 40.29405656316387 minutes in Zone 1R.
# Patient 10 discharged at time 161.52987647244365.
# Patient 10 assigned category at time 161.52987647244365
# Patient 11 arrived by ambulance at time 161.52987647244365.
# Patient 11 categorized as Non-Trauma.
# Patient 11 labelled as Non-Urgent.
# Patient 11 moved to Waiting Room at time 175.7574525197078. Number of people in the waiting room: 3
# Patient 11 assigned category at time 175.7574525197078
# Patient 15 arrived by ambulance at time 175.7574525197078.
# Patient 15 is a traum patient, cannot be diverted.
# Patient 15 moved to Zone 1R at time 175.7574525197078.
# Patient 5 spent 71.38449698221211 minutes in Zone 4.
# Patient 5 discharged at time 185.11255476168762.
# Patient 5 arrived as walk-in (['Referred']) at time 4
# Patient 5 assigned category at time 4
# Patient 7 moved to Waiting Room at time 195.4407955390564. Number of people in the waiting room: 4
# Patient 7 moved to Zone 4 at time 195.4407955390564. Number of people in the waiting room: 3
# Patient 7 spent 87.84668374687739 minutes in Zone 4.
# Patient 7 discharged at time 283.2874792859338.
# Patient 7 arrived as walk-in (['Urgent']) at time 6
# Patient 7 assigned category at time 6
# Patient 8 moved to Waiting Room at time 298.19843321683163. Number of people in the waiting room: 4
# Patient 8 moved to Zone 3 at time 298.19843321683163. Number of people in the waiting room: 3
# Patient 15 spent 132.86330267393828 minutes in Zone 1R.
# Patient 15 discharged at time 308.6207551936461.
# Patient 15 assigned category at time 308.6207551936461
# Patient 19 arrived by ambulance at time 308.6207551936461.
# Patient 19 categorized as Non-Trauma.
# Patient 19 labelled as Non-Urgent.
# Patient 19 moved to Waiting Room at time 319.0473471020104. Number of people in the waiting room: 4
# Patient 19 assigned category at time 319.0473471020104
# Patient 23 arrived by ambulance at time 319.0473471020104.
# Patient 23 categorized as Non-Trauma.
# Patient 23 labelled as Non-Urgent.
# Patient 8 spent 31.02970579922019 minutes in Zone 3.
# Patient 8 discharged at time 329.22813901605184.
# Patient 8 arrived as walk-in (['Referred']) at time 7
# Patient 8 assigned category at time 7
# Patient 23 moved to Waiting Room at time 333.08633916439794. Number of people in the waiting room: 5
# Patient 23 assigned category at time 333.08633916439794
# Patient 26 arrived by ambulance at time 333.08633916439794.
# Patient 26 categorized as Non-Trauma.
# Patient 26 labelled as Non-Urgent.
# Patient 9 moved to Waiting Room at time 341.31815216921285. Number of people in the waiting room: 6
# Patient 9 moved to Zone 4 at time 341.31815216921285. Number of people in the waiting room: 5
# Patient 26 moved to Waiting Room at time 347.37522335923086. Number of people in the waiting room: 6
# Patient 26 assigned category at time 347.37522335923086
# Patient 31 arrived by ambulance at time 347.37522335923086.
# Patient 31 categorized as Non-Trauma.
# Patient 31 labelled as Non-Urgent.
# Patient 31 moved to Waiting Room at time 361.023776067387. Number of people in the waiting room: 7
# Patient 31 assigned category at time 361.023776067387
# Patient 33 arrived by ambulance at time 361.023776067387.
# Patient 33 is a traum patient, cannot be diverted.
# Patient 33 moved to Zone 1R at time 361.023776067387.
# Patient 9 spent 46.032044037935734 minutes in Zone 4.
# Patient 9 discharged at time 387.3501962071486.
# Patient 9 arrived as walk-in (['Non-Urgent']) at time 8
# Patient 9 assigned category at time 8
# Patient 12 moved to Waiting Room at time 400.62860220658274. Number of people in the waiting room: 8
# Patient 12 moved to Zone 4 at time 400.62860220658274. Number of people in the waiting room: 7
# Patient 12 spent 49.40739553412368 minutes in Zone 4.
# Patient 12 discharged at time 450.0359977407064.
# Patient 12 arrived as walk-in (['Urgent']) at time 11
# Patient 12 assigned category at time 11
# Patient 13 moved to Waiting Room at time 464.2943900562084. Number of people in the waiting room: 8
# Patient 13 moved to Zone 3 at time 464.2943900562084. Number of people in the waiting room: 7
# Patient 33 spent 104.93401807478627 minutes in Zone 1R.
# Patient 33 discharged at time 465.95779414217327.
# Patient 33 assigned category at time 465.95779414217327
# Patient 35 arrived by ambulance at time 465.95779414217327.
# Patient 35 categorized as Non-Trauma.
# Patient 35 labelled as Non-Urgent.
# Patient 35 moved to Waiting Room at time 480.04830334849396. Number of people in the waiting room: 8
# Patient 35 assigned category at time 480.04830334849396
# Patient 36 arrived by ambulance at time 480.04830334849396.
# Patient 36 is a traum patient, cannot be diverted.
# Patient 36 moved to Zone 1R at time 480.04830334849396.
# Patient 13 spent 35.653498754030835 minutes in Zone 3.
# Patient 13 discharged at time 499.9478888102392.
# Patient 13 arrived as walk-in (['Non-Urgent']) at time 12
# Patient 13 assigned category at time 12
# Patient 14 moved to Waiting Room at time 513.3046875844979. Number of people in the waiting room: 9
# Patient 14 moved to Zone 3 at time 513.3046875844979. Number of people in the waiting room: 8
# Patient 14 spent 26.54520828220526 minutes in Zone 3.
# Patient 14 discharged at time 539.8498958667032.
# Patient 14 arrived as walk-in (['Urgent']) at time 13
# Patient 14 assigned category at time 13
# Patient 16 moved to Waiting Room at time 552.1863500279204. Number of people in the waiting room: 9
# Patient 16 moved to Zone 3 at time 552.1863500279204. Number of people in the waiting room: 8
# Patient 16 spent 22.385628131925625 minutes in Zone 3.
# Patient 16 discharged at time 574.571978159846.
# Patient 16 arrived as walk-in (['Non-Urgent']) at time 15
# Patient 16 assigned category at time 15
# Patient 17 moved to Waiting Room at time 588.8292309680498. Number of people in the waiting room: 9
# Patient 17 moved to Zone 3 at time 588.8292309680498. Number of people in the waiting room: 8
# Patient 17 spent 39.08344630175303 minutes in Zone 3.
# Patient 17 discharged at time 627.9126772698029.
# Patient 17 arrived as walk-in (['Referred']) at time 16
# Patient 17 assigned category at time 16
# Patient 36 spent 148.43992931824374 minutes in Zone 1R.
# Patient 36 discharged at time 628.4882326667378.
# Patient 36 assigned category at time 628.4882326667378
# Patient 37 arrived by ambulance at time 628.4882326667378.
# Patient 37 categorized as Non-Trauma.
# Patient 37 labelled as Non-Urgent.
# Patient 18 moved to Waiting Room at time 639.4862310293388. Number of people in the waiting room: 9
# Patient 18 moved to Zone 4 at time 639.4862310293388. Number of people in the waiting room: 8
# Patient 37 moved to Waiting Room at time 640.1941375804555. Number of people in the waiting room: 9
# Patient 37 assigned category at time 640.1941375804555
# Patient 38 arrived by ambulance at time 640.1941375804555.
# Patient 38 categorized as Non-Trauma.
# Patient 38 labelled as Non-Urgent.
# Patient 38 moved to Waiting Room at time 652.5732697399399. Number of people in the waiting room: 10
# Patient 38 assigned category at time 652.5732697399399
# Patient 39 arrived by ambulance at time 652.5732697399399.
# Patient 39 categorized as Non-Trauma.
# Patient 39 labelled as Non-Urgent.
# Patient 39 moved to Waiting Room at time 662.8615882658062. Number of people in the waiting room: 11
# Patient 39 assigned category at time 662.8615882658062
# Patient 40 arrived by ambulance at time 662.8615882658062.
# Patient 40 is a traum patient, cannot be diverted.
# Patient 40 moved to Zone 1R at time 662.8615882658062.
# Patient 18 spent 51.11638325451658 minutes in Zone 4.
# Patient 18 discharged at time 690.6026142838554.
# Patient 18 arrived as walk-in (['Urgent']) at time 17
# Patient 18 assigned category at time 17
# Patient 20 moved to Waiting Room at time 703.0027342137118. Number of people in the waiting room: 12
# Patient 20 moved to Zone 3 at time 703.0027342137118. Number of people in the waiting room: 11
# Patient 20 spent 72.62207390263475 minutes in Zone 3.
# Patient 20 discharged at time 775.6248081163466.
# Patient 20 arrived as walk-in (['Non-Urgent']) at time 19
# Patient 20 assigned category at time 19
# Patient 21 moved to Waiting Room at time 790.0836550728138. Number of people in the waiting room: 12
# Patient 21 moved to Zone 4 at time 790.0836550728138. Number of people in the waiting room: 11
# Patient 40 spent 143.6332058077694 minutes in Zone 1R.
# Patient 40 discharged at time 806.4947940735756.
# Patient 40 assigned category at time 806.4947940735756
# Patient 42 arrived by ambulance at time 806.4947940735756.
# Patient 42 is a traum patient, cannot be diverted.
# Patient 42 moved to Zone 1R at time 806.4947940735756.
# Patient 21 spent 68.1600559540805 minutes in Zone 4.
# Patient 21 discharged at time 858.2437110268943.
# Patient 21 arrived as walk-in (['Non-Urgent']) at time 20
# Patient 21 assigned category at time 20
# Patient 42 spent 56.372491245899084 minutes in Zone 1R.
# Patient 42 discharged at time 862.8672853194746.
# Patient 42 assigned category at time 862.8672853194746
# Patient 45 arrived by ambulance at time 862.8672853194746.
# Patient 45 categorized as Non-Trauma.
# Patient 45 labelled as Non-Urgent.
# Patient 22 moved to Waiting Room at time 870.230271167867. Number of people in the waiting room: 12
# Patient 22 moved to Zone 4 at time 870.230271167867. Number of people in the waiting room: 11
# Patient 45 moved to Waiting Room at time 875.9019266575395. Number of people in the waiting room: 12
# Patient 45 assigned category at time 875.9019266575395
# Patient 50 arrived by ambulance at time 875.9019266575395.
# Patient 50 is a traum patient, cannot be diverted.
# Patient 50 moved to Zone 1R at time 875.9019266575395.
# Patient 22 spent 25.1510178483757 minutes in Zone 4.
# Patient 22 discharged at time 895.3812890162427.
# Patient 22 arrived as walk-in (['Non-Urgent']) at time 21
# Patient 22 assigned category at time 21
# Patient 24 moved to Waiting Room at time 908.9221065869851. Number of people in the waiting room: 13
# Patient 24 moved to Zone 3 at time 908.9221065869851. Number of people in the waiting room: 12
# Patient 24 spent 76.29053751499694 minutes in Zone 3.
# Patient 24 discharged at time 985.212644101982.
# Patient 24 arrived as walk-in (['Urgent']) at time 23
# Patient 24 assigned category at time 23
# Patient 25 moved to Waiting Room at time 999.172588169238. Number of people in the waiting room: 13
# Patient 25 moved to Zone 3 at time 999.172588169238. Number of people in the waiting room: 12
# Patient 50 spent 141.06869668775067 minutes in Zone 1R.
# Patient 50 discharged at time 1016.9706233452903.
# Patient 50 assigned category at time 1016.9706233452903
# Patient 51 arrived by ambulance at time 1016.9706233452903.
# Patient 51 is a traum patient, cannot be diverted.
# Patient 51 moved to Zone 1R at time 1016.9706233452903.
# Patient 25 spent 21.72765995096393 minutes in Zone 3.
# Patient 25 discharged at time 1020.9002481202019.
# Patient 25 arrived as walk-in (['Urgent']) at time 24
# Patient 25 assigned category at time 24
# Patient 27 moved to Waiting Room at time 1035.775787576551. Number of people in the waiting room: 13
# Patient 27 moved to Zone 4 at time 1035.775787576551. Number of people in the waiting room: 12
# Patient 27 spent 89.0573292622653 minutes in Zone 4.
# Patient 27 discharged at time 1124.8331168388163.
# Patient 27 arrived as walk-in (['Referred']) at time 26
# Patient 27 assigned category at time 26
# Patient 28 moved to Waiting Room at time 1137.4545737361218. Number of people in the waiting room: 13
# Patient 28 moved to Zone 3 at time 1137.4545737361218. Number of people in the waiting room: 12
# Patient 51 spent 173.69007676086028 minutes in Zone 1R.
# Patient 51 discharged at time 1190.6607001061507.
# Patient 51 assigned category at time 1190.6607001061507
# Patient 53 arrived by ambulance at time 1190.6607001061507.
# Patient 53 is a traum patient, cannot be diverted.
# Patient 53 moved to Zone 1R at time 1190.6607001061507.
# Patient 28 spent 80.46663798922009 minutes in Zone 3.
# Patient 28 discharged at time 1217.921211725342.
# Patient 28 arrived as walk-in (['Non-Urgent']) at time 27
# Patient 28 assigned category at time 27
# Patient 29 moved to Waiting Room at time 1228.1962441010646. Number of people in the waiting room: 13
# Patient 29 moved to Zone 3 at time 1228.1962441010646. Number of people in the waiting room: 12
# Patient 29 spent 61.70427119809281 minutes in Zone 3.
# Patient 29 discharged at time 1289.9005152991574.
# Patient 29 arrived as walk-in (['Urgent']) at time 28
# Patient 29 assigned category at time 28
# Patient 53 spent 100.85124933830431 minutes in Zone 1R.
# Patient 53 discharged at time 1291.511949444455.
# Patient 53 assigned category at time 1291.511949444455
# Patient 57 arrived by ambulance at time 1291.511949444455.
# Patient 57 is a traum patient, cannot be diverted.
# Patient 57 moved to Zone 1R at time 1291.511949444455.
# Patient 30 moved to Waiting Room at time 1303.175703970481. Number of people in the waiting room: 13
# Patient 30 moved to Zone 3 at time 1303.175703970481. Number of people in the waiting room: 12
# Patient 30 spent 87.82277830333331 minutes in Zone 3.
# Patient 30 discharged at time 1390.9984822738143.
# Patient 30 arrived as walk-in (['Urgent']) at time 29
# Patient 30 assigned category at time 29
# Patient 32 moved to Waiting Room at time 1403.7115058348581. Number of people in the waiting room: 13
# Patient 32 moved to Zone 4 at time 1403.7115058348581. Number of people in the waiting room: 12
# Patient 57 spent 119.49844454168664 minutes in Zone 1R.
# Patient 57 discharged at time 1411.0103939861417.
# Patient 57 assigned category at time 1411.0103939861417
# Patient 59 arrived by ambulance at time 1411.0103939861417.
# Patient 59 is a traum patient, cannot be diverted.
# Patient 59 moved to Zone 1R at time 1411.0103939861417.
# Patient 32 spent 41.27756657602424 minutes in Zone 4.
# Patient 32 discharged at time 1444.9890724108823.
# Patient 32 arrived as walk-in (['Urgent']) at time 31
# Patient 32 assigned category at time 31
# Patient 34 moved to Waiting Room at time 1456.3315013726087. Number of people in the waiting room: 13
# Patient 34 moved to Zone 3 at time 1456.3315013726087. Number of people in the waiting room: 12
# Patient 59 spent 70.12109048302688 minutes in Zone 1R.
# Patient 59 discharged at time 1481.1314844691685.
# Patient 59 assigned category at time 1481.1314844691685
# Patient 65 arrived by ambulance at time 1481.1314844691685.
# Patient 65 is a traum patient, cannot be diverted.
# Patient 65 moved to Zone 1R at time 1481.1314844691685.
# Patient 34 spent 62.69580088660572 minutes in Zone 3.
# Patient 34 discharged at time 1519.0273022592144.
# Patient 34 arrived as walk-in (['Referred']) at time 33
# Patient 34 assigned category at time 33
# Patient 41 moved to Waiting Room at time 1530.3628645976723. Number of people in the waiting room: 13
# Patient 41 moved to Zone 4 at time 1530.3628645976723. Number of people in the waiting room: 12
# Patient 41 spent 73.13289067462533 minutes in Zone 4.
# Patient 41 discharged at time 1603.4957552722976.
# Patient 41 arrived as walk-in (['Referred']) at time 40
# Patient 41 assigned category at time 40
# Patient 43 moved to Waiting Room at time 1615.1510762770802. Number of people in the waiting room: 13
# Patient 43 moved to Zone 4 at time 1615.1510762770802. Number of people in the waiting room: 12
# Patient 65 spent 145.23955100233496 minutes in Zone 1R.
# Patient 65 discharged at time 1626.3710354715035.
# Patient 65 assigned category at time 1626.3710354715035
# Patient 72 arrived by ambulance at time 1626.3710354715035.
# Patient 72 is a traum patient, cannot be diverted.
# Patient 72 moved to Zone 1R at time 1626.3710354715035.
# Patient 43 spent 73.42348488399989 minutes in Zone 4.
# Patient 43 discharged at time 1688.57456116108.
# Patient 43 arrived as walk-in (['Non-Urgent']) at time 42
# Patient 43 assigned category at time 42
# Patient 44 moved to Waiting Room at time 1699.304490713471. Number of people in the waiting room: 13
# Patient 44 moved to Zone 3 at time 1699.304490713471. Number of people in the waiting room: 12
# Patient 72 spent 77.29971977115144 minutes in Zone 1R.
# Patient 72 discharged at time 1703.670755242655.
# Patient 72 assigned category at time 1703.670755242655
# Patient 75 arrived by ambulance at time 1703.670755242655.
# Patient 75 is a traum patient, cannot be diverted.
# Patient 75 moved to Zone 1R at time 1703.670755242655.
# Patient 44 spent 23.188586988232373 minutes in Zone 3.
# Patient 44 discharged at time 1722.4930777017034.
# Patient 44 arrived as walk-in (['Non-Urgent']) at time 43
# Patient 44 assigned category at time 43
# Patient 46 moved to Waiting Room at time 1732.8998587421045. Number of people in the waiting room: 13
# Patient 46 moved to Zone 3 at time 1732.8998587421045. Number of people in the waiting room: 12
# Patient 75 spent 44.77087913431178 minutes in Zone 1R.
# Patient 75 discharged at time 1748.441634376967.
# Patient 75 assigned category at time 1748.441634376967
# Patient 79 arrived by ambulance at time 1748.441634376967.
# Patient 79 categorized as Non-Trauma.
# Patient 79 labelled as Non-Urgent.
# Patient 79 moved to Waiting Room at time 1759.786972103638. Number of people in the waiting room: 13
# Patient 79 assigned category at time 1759.786972103638
# Patient 82 arrived by ambulance at time 1759.786972103638.
# Patient 82 is a traum patient, cannot be diverted.
# Patient 82 moved to Zone 1R at time 1759.786972103638.
# Patient 46 spent 85.23459446744752 minutes in Zone 3.
# Patient 46 discharged at time 1818.134453209552.
# Patient 46 arrived as walk-in (['Referred']) at time 45
# Patient 46 assigned category at time 45
# Patient 47 moved to Waiting Room at time 1832.436236331978. Number of people in the waiting room: 14
# Patient 47 moved to Zone 3 at time 1832.436236331978. Number of people in the waiting room: 13
# Patient 82 spent 98.54859646864233 minutes in Zone 1R.
# Patient 82 discharged at time 1858.3355685722802.
# Patient 82 assigned category at time 1858.3355685722802
# Patient 83 arrived by ambulance at time 1858.3355685722802.
# Patient 83 categorized as Non-Trauma.
# Patient 83 labelled as Non-Urgent.
# Patient 83 moved to Waiting Room at time 1868.8202999831096. Number of people in the waiting room: 14
# Patient 83 assigned category at time 1868.8202999831096
# Patient 85 arrived by ambulance at time 1868.8202999831096.
# Patient 85 categorized as Non-Trauma.
# Patient 85 labelled as Non-Urgent.
# Patient 85 moved to Waiting Room at time 1883.7814405131894. Number of people in the waiting room: 15
# Patient 85 assigned category at time 1883.7814405131894
# Patient 87 arrived by ambulance at time 1883.7814405131894.
# Patient 87 categorized as Non-Trauma.
# Patient 87 labelled as Non-Urgent.
# Patient 87 moved to Waiting Room at time 1895.510480724196. Number of people in the waiting room: 16
# Patient 87 assigned category at time 1895.510480724196
# Patient 89 arrived by ambulance at time 1895.510480724196.
# Patient 89 is a traum patient, cannot be diverted.
# Patient 89 moved to Zone 1R at time 1895.510480724196.
# Patient 47 spent 83.14239398804821 minutes in Zone 3.
# Patient 47 discharged at time 1915.5786303200264.
# Patient 47 arrived as walk-in (['Referred']) at time 46
# Patient 47 assigned category at time 46
# Patient 48 moved to Waiting Room at time 1927.5786960424132. Number of people in the waiting room: 17
# Patient 48 moved to Zone 3 at time 1927.5786960424132. Number of people in the waiting room: 16
# Patient 89 spent 78.8196005770441 minutes in Zone 1R.
# Patient 89 discharged at time 1974.3300813012402.
# Patient 89 assigned category at time 1974.3300813012402
# Patient 90 arrived by ambulance at time 1974.3300813012402.
# Patient 90 categorized as Non-Trauma.
# Patient 90 labelled as Non-Urgent.
# Patient 48 spent 52.81071365365073 minutes in Zone 3.
# Patient 48 discharged at time 1980.389409696064.
# Patient 48 arrived as walk-in (['Urgent']) at time 47
# Patient 48 assigned category at time 47
# Patient 90 moved to Waiting Room at time 1989.030159482336. Number of people in the waiting room: 17
# Patient 90 assigned category at time 1989.030159482336
# Patient 96 arrived by ambulance at time 1989.030159482336.
# Patient 96 is a traum patient, cannot be diverted.
# Patient 96 moved to Zone 1R at time 1989.030159482336.
# Patient 49 moved to Waiting Room at time 1992.0547661237354. Number of people in the waiting room: 18
# Patient 49 moved to Zone 4 at time 1992.0547661237354. Number of people in the waiting room: 17
# Patient 49 spent 57.05162503766382 minutes in Zone 4.
# Patient 49 discharged at time 2049.106391161399.
# Patient 49 arrived as walk-in (['Urgent']) at time 48
# Patient 49 assigned category at time 48
# Patient 52 moved to Waiting Room at time 2061.6745241487197. Number of people in the waiting room: 18
# Patient 52 moved to Zone 4 at time 2061.6745241487197. Number of people in the waiting room: 17
# Patient 96 spent 115.33220829054574 minutes in Zone 1R.
# Patient 96 discharged at time 2104.362367772882.
# Patient 96 assigned category at time 2104.362367772882
# Patient 98 arrived by ambulance at time 2104.362367772882.
# Patient 98 is a traum patient, cannot be diverted.
# Patient 98 moved to Zone 1R at time 2104.362367772882.
# Patient 52 spent 62.37900260236716 minutes in Zone 4.
# Patient 52 discharged at time 2124.053526751087.
# Patient 52 arrived as walk-in (['Urgent']) at time 51
# Patient 52 assigned category at time 51
# Patient 54 moved to Waiting Room at time 2136.4896100811843. Number of people in the waiting room: 18
# Patient 54 moved to Zone 4 at time 2136.4896100811843. Number of people in the waiting room: 17
# Patient 98 spent 55.12773697959707 minutes in Zone 1R.
# Patient 98 discharged at time 2159.490104752479.
# Patient 98 assigned category at time 2159.490104752479
# Patient 102 arrived by ambulance at time 2159.490104752479.
# Patient 102 categorized as Non-Trauma.
# Patient 102 labelled as Non-Urgent.
# Patient 102 moved to Waiting Room at time 2171.3785324821456. Number of people in the waiting room: 18
# Patient 102 assigned category at time 2171.3785324821456
# Patient 103 arrived by ambulance at time 2171.3785324821456.
# Patient 103 is a traum patient, cannot be diverted.
# Patient 103 moved to Zone 1R at time 2171.3785324821456.
# Patient 54 spent 56.29893901580177 minutes in Zone 4.
# Patient 54 discharged at time 2192.788549096986.
# Patient 54 arrived as walk-in (['Non-Urgent']) at time 53
# Patient 54 assigned category at time 53
# Patient 55 moved to Waiting Room at time 2207.435501789242. Number of people in the waiting room: 19
# Patient 55 moved to Zone 4 at time 2207.435501789242. Number of people in the waiting room: 18
# Patient 55 spent 23.74441097238702 minutes in Zone 4.
# Patient 55 discharged at time 2231.179912761629.
# Patient 55 arrived as walk-in (['Referred']) at time 54
# Patient 55 assigned category at time 54
# Patient 56 moved to Waiting Room at time 2245.762539097971. Number of people in the waiting room: 19
# Patient 56 moved to Zone 3 at time 2245.762539097971. Number of people in the waiting room: 18
# Patient 103 spent 108.93004536861974 minutes in Zone 1R.
# Patient 103 discharged at time 2280.3085778507652.
# Patient 103 assigned category at time 2280.3085778507652
# Patient 111 arrived by ambulance at time 2280.3085778507652.
# Patient 111 is a traum patient, cannot be diverted.
# Patient 111 moved to Zone 1R at time 2280.3085778507652.
# Patient 56 spent 67.3604743530219 minutes in Zone 3.
# Patient 56 discharged at time 2313.123013450993.
# Patient 56 arrived as walk-in (['Urgent']) at time 55
# Patient 56 assigned category at time 55
# Patient 58 moved to Waiting Room at time 2326.5478677633578. Number of people in the waiting room: 19
# Patient 58 moved to Zone 4 at time 2326.5478677633578. Number of people in the waiting room: 18
# Patient 58 spent 35.81615527638205 minutes in Zone 4.
# Patient 58 discharged at time 2362.36402303974.
# Patient 58 arrived as walk-in (['Referred']) at time 57
# Patient 58 assigned category at time 57
# Patient 60 moved to Waiting Room at time 2374.7201103955645. Number of people in the waiting room: 19
# Patient 60 moved to Zone 4 at time 2374.7201103955645. Number of people in the waiting room: 18
# Patient 60 spent 24.152702347091616 minutes in Zone 4.
# Patient 60 discharged at time 2398.872812742656.
# Patient 60 arrived as walk-in (['Referred']) at time 59
# Patient 60 assigned category at time 59
# Patient 111 spent 126.50061992298501 minutes in Zone 1R.
# Patient 111 discharged at time 2406.8091977737504.
# Patient 111 assigned category at time 2406.8091977737504
# Patient 113 arrived by ambulance at time 2406.8091977737504.
# Patient 113 categorized as Non-Trauma.
# Patient 113 labelled as Non-Urgent.
# Patient 61 moved to Waiting Room at time 2410.148888106125. Number of people in the waiting room: 19
# Patient 61 moved to Zone 4 at time 2410.148888106125. Number of people in the waiting room: 18
# Patient 113 moved to Waiting Room at time 2420.9800130645544. Number of people in the waiting room: 19
# Patient 113 assigned category at time 2420.9800130645544
# Patient 118 arrived by ambulance at time 2420.9800130645544.
# Patient 118 categorized as Non-Trauma.
# Patient 118 labelled as Non-Urgent.
# Patient 61 spent 22.00964055923344 minutes in Zone 4.
# Patient 61 discharged at time 2432.1585286653585.
# Patient 61 arrived as walk-in (['Urgent']) at time 60
# Patient 61 assigned category at time 60
# Patient 118 moved to Waiting Room at time 2434.984037411158. Number of people in the waiting room: 20
# Patient 118 assigned category at time 2434.984037411158
# Patient 123 arrived by ambulance at time 2434.984037411158.
# Patient 123 categorized as Non-Trauma.
# Patient 123 labelled as Non-Urgent.
# Patient 123 moved to Waiting Room at time 2445.229671758439. Number of people in the waiting room: 21
# Patient 123 assigned category at time 2445.229671758439
# Patient 125 arrived by ambulance at time 2445.229671758439.
# Patient 125 categorized as Non-Trauma.
# Patient 125 labelled as Non-Urgent.
# Patient 62 moved to Waiting Room at time 2446.7191757379055. Number of people in the waiting room: 22
# Patient 62 moved to Zone 4 at time 2446.7191757379055. Number of people in the waiting room: 21
# Patient 125 moved to Waiting Room at time 2457.0302499405148. Number of people in the waiting room: 22
# Patient 125 assigned category at time 2457.0302499405148
# Patient 128 arrived by ambulance at time 2457.0302499405148.
# Patient 128 is a traum patient, cannot be diverted.
# Patient 128 moved to Zone 1R at time 2457.0302499405148.
# Patient 62 spent 25.37876841114603 minutes in Zone 4.
# Patient 62 discharged at time 2472.0979441490517.
# Patient 62 arrived as walk-in (['Urgent']) at time 61
# Patient 62 assigned category at time 61
# Patient 63 moved to Waiting Room at time 2485.24446247752. Number of people in the waiting room: 23
# Patient 63 moved to Zone 3 at time 2485.24446247752. Number of people in the waiting room: 22
# Patient 63 spent 50.3575507332331 minutes in Zone 3.
# Patient 63 discharged at time 2535.602013210753.
# Patient 63 arrived as walk-in (['Urgent']) at time 62
# Patient 63 assigned category at time 62
# Patient 64 moved to Waiting Room at time 2548.3856985277826. Number of people in the waiting room: 23
# Patient 64 moved to Zone 4 at time 2548.3856985277826. Number of people in the waiting room: 22
# Patient 64 spent 59.50601835310837 minutes in Zone 4.
# Patient 64 discharged at time 2607.8917168808907.
# Patient 64 arrived as walk-in (['Non-Urgent']) at time 63
# Patient 64 assigned category at time 63
# Patient 66 moved to Waiting Room at time 2618.4233418448384. Number of people in the waiting room: 23
# Patient 66 moved to Zone 3 at time 2618.4233418448384. Number of people in the waiting room: 22
# Patient 128 spent 168.20958125698397 minutes in Zone 1R.
# Patient 128 discharged at time 2625.239831197499.
# Patient 128 assigned category at time 2625.239831197499
# Patient 142 arrived by ambulance at time 2625.239831197499.
# Patient 142 is a traum patient, cannot be diverted.
# Patient 142 moved to Zone 1R at time 2625.239831197499.
# Patient 66 spent 66.28938463147239 minutes in Zone 3.
# Patient 66 discharged at time 2684.7127264763108.
# Patient 66 arrived as walk-in (['Urgent']) at time 65
# Patient 66 assigned category at time 65
# Patient 67 moved to Waiting Room at time 2697.035230342635. Number of people in the waiting room: 23
# Patient 67 moved to Zone 3 at time 2697.035230342635. Number of people in the waiting room: 22
# Patient 67 spent 37.147101605184496 minutes in Zone 3.
# Patient 67 discharged at time 2734.1823319478194.
# Patient 67 arrived as walk-in (['Urgent']) at time 66
# Patient 67 assigned category at time 66
# Patient 68 moved to Waiting Room at time 2746.8817862831793. Number of people in the waiting room: 23
# Patient 68 moved to Zone 3 at time 2746.8817862831793. Number of people in the waiting room: 22
# Patient 142 spent 164.9434819190152 minutes in Zone 1R.
# Patient 142 discharged at time 2790.183313116514.
# Patient 142 assigned category at time 2790.183313116514
# Patient 145 arrived by ambulance at time 2790.183313116514.
# Patient 145 is a traum patient, cannot be diverted.
# Patient 145 moved to Zone 1R at time 2790.183313116514.
# Patient 68 spent 49.41676592699069 minutes in Zone 3.
# Patient 68 discharged at time 2796.29855221017.
# Patient 68 arrived as walk-in (['Non-Urgent']) at time 67
# Patient 68 assigned category at time 67
# Patient 69 moved to Waiting Room at time 2807.8911620504514. Number of people in the waiting room: 23
# Patient 69 moved to Zone 4 at time 2807.8911620504514. Number of people in the waiting room: 22
# Patient 69 spent 48.05946061106864 minutes in Zone 4.
# Patient 69 discharged at time 2855.95062266152.
# Patient 69 arrived as walk-in (['Non-Urgent']) at time 68
# Patient 69 assigned category at time 68
# Patient 70 moved to Waiting Room at time 2870.4046931624266. Number of people in the waiting room: 23
# Patient 70 moved to Zone 4 at time 2870.4046931624266. Number of people in the waiting room: 22
# Patient 70 spent 52.80029325713611 minutes in Zone 4.
# Patient 70 discharged at time 2923.204986419563.
# Patient 70 arrived as walk-in (['Non-Urgent']) at time 69
# Patient 70 assigned category at time 69
# Patient 71 moved to Waiting Room at time 2935.4821772417754. Number of people in the waiting room: 23
# Patient 71 moved to Zone 3 at time 2935.4821772417754. Number of people in the waiting room: 22
# Patient 145 spent 159.54126442041434 minutes in Zone 1R.
# Patient 145 discharged at time 2949.7245775369283.
# Patient 145 assigned category at time 2949.7245775369283
# Patient 146 arrived by ambulance at time 2949.7245775369283.
# Patient 146 categorized as Non-Trauma.
# Patient 146 labelled as Non-Urgent.
# Patient 146 moved to Waiting Room at time 2964.6399495336777. Number of people in the waiting room: 23
# Patient 146 assigned category at time 2964.6399495336777
# Patient 147 arrived by ambulance at time 2964.6399495336777.
# Patient 147 is a traum patient, cannot be diverted.
# Patient 147 moved to Zone 1R at time 2964.6399495336777.
# Patient 71 spent 53.08026788734543 minutes in Zone 3.
# Patient 71 discharged at time 2988.562445129121.
# Patient 71 arrived as walk-in (['Urgent']) at time 70
# Patient 71 assigned category at time 70
# Patient 73 moved to Waiting Room at time 3002.989222380497. Number of people in the waiting room: 24
# Patient 73 moved to Zone 4 at time 3002.989222380497. Number of people in the waiting room: 23
# Patient 73 spent 67.43843152623558 minutes in Zone 4.
# Patient 73 discharged at time 3070.4276539067323.
# Patient 73 arrived as walk-in (['Urgent']) at time 72
# Patient 73 assigned category at time 72
# Patient 74 moved to Waiting Room at time 3085.39303722464. Number of people in the waiting room: 24
# Patient 74 moved to Zone 4 at time 3085.39303722464. Number of people in the waiting room: 23
# Patient 147 spent 136.51845932236796 minutes in Zone 1R.
# Patient 147 discharged at time 3101.1584088560458.
# Patient 147 assigned category at time 3101.1584088560458
# Patient 149 arrived by ambulance at time 3101.1584088560458.
# Patient 149 categorized as Non-Trauma.
# Patient 149 labelled as Non-Urgent.
# Patient 149 moved to Waiting Room at time 3116.0806111369075. Number of people in the waiting room: 24
# Patient 149 assigned category at time 3116.0806111369075
# Patient 150 arrived by ambulance at time 3116.0806111369075.
# Patient 150 is a traum patient, cannot be diverted.
# Patient 150 moved to Zone 1R at time 3116.0806111369075.
# Patient 74 spent 49.318612180550005 minutes in Zone 4.
# Patient 74 discharged at time 3134.71164940519.
# Patient 74 arrived as walk-in (['Referred']) at time 73
# Patient 74 assigned category at time 73
# Patient 76 moved to Waiting Room at time 3147.8157759300643. Number of people in the waiting room: 25
# Patient 76 moved to Zone 4 at time 3147.8157759300643. Number of people in the waiting room: 24
# Patient 150 spent 50.78214562406212 minutes in Zone 1R.
# Patient 150 discharged at time 3166.8627567609697.
# Patient 150 assigned category at time 3166.8627567609697
# Patient 154 arrived by ambulance at time 3166.8627567609697.
# Patient 154 is a traum patient, cannot be diverted.
# Patient 154 moved to Zone 1R at time 3166.8627567609697.
# Patient 76 spent 81.13992682656558 minutes in Zone 4.
# Patient 76 discharged at time 3228.9557027566298.
# Patient 76 arrived as walk-in (['Urgent']) at time 75
# Patient 76 assigned category at time 75
# Patient 77 moved to Waiting Room at time 3240.5704520249033. Number of people in the waiting room: 25
# Patient 77 moved to Zone 3 at time 3240.5704520249033. Number of people in the waiting room: 24
# Patient 77 spent 58.15159702936941 minutes in Zone 3.
# Patient 77 discharged at time 3298.7220490542727.
# Patient 77 arrived as walk-in (['Urgent']) at time 76
# Patient 77 assigned category at time 76
# Patient 154 spent 135.83673873259863 minutes in Zone 1R.
# Patient 154 discharged at time 3302.699495493568.
# Patient 154 assigned category at time 3302.699495493568
# Patient 158 arrived by ambulance at time 3302.699495493568.
# Patient 158 categorized as Non-Trauma.
# Patient 158 labelled as Non-Urgent.
# Patient 78 moved to Waiting Room at time 3312.309812308601. Number of people in the waiting room: 25
# Patient 78 moved to Zone 4 at time 3312.309812308601. Number of people in the waiting room: 24
# Patient 158 moved to Waiting Room at time 3314.7568811097717. Number of people in the waiting room: 25
# Patient 158 assigned category at time 3314.7568811097717
# Patient 161 arrived by ambulance at time 3314.7568811097717.
# Patient 161 is a traum patient, cannot be diverted.
# Patient 161 moved to Zone 1R at time 3314.7568811097717.
# Patient 78 spent 21.595149441508095 minutes in Zone 4.
# Patient 78 discharged at time 3333.904961750109.
# Patient 78 arrived as walk-in (['Non-Urgent']) at time 77
# Patient 78 assigned category at time 77
# Patient 80 moved to Waiting Room at time 3348.3345058684467. Number of people in the waiting room: 26
# Patient 80 moved to Zone 3 at time 3348.3345058684467. Number of people in the waiting room: 25
# Patient 161 spent 85.58346564317242 minutes in Zone 1R.
# Patient 161 discharged at time 3400.3403467529442.
# Patient 161 assigned category at time 3400.3403467529442
# Patient 163 arrived by ambulance at time 3400.3403467529442.
# Patient 163 is a traum patient, cannot be diverted.
# Patient 163 moved to Zone 1R at time 3400.3403467529442.
# Patient 80 spent 79.12818966130034 minutes in Zone 3.
# Patient 80 discharged at time 3427.462695529747.
# Patient 80 arrived as walk-in (['Non-Urgent']) at time 79
# Patient 80 assigned category at time 79
# Patient 81 moved to Waiting Room at time 3438.7034162028986. Number of people in the waiting room: 26
# Patient 81 moved to Zone 4 at time 3438.7034162028986. Number of people in the waiting room: 25
# Patient 163 spent 63.50448928956904 minutes in Zone 1R.
# Patient 163 discharged at time 3463.844836042513.
# Patient 163 assigned category at time 3463.844836042513
# Patient 169 arrived by ambulance at time 3463.844836042513.
# Patient 169 categorized as Non-Trauma.
# Patient 169 labelled as Non-Urgent.
# Patient 81 spent 32.45032692159178 minutes in Zone 4.
# Patient 81 discharged at time 3471.15374312449.
# Patient 81 arrived as walk-in (['Urgent']) at time 80
# Patient 81 assigned category at time 80
# Patient 169 moved to Waiting Room at time 3474.2640136137575. Number of people in the waiting room: 26
# Patient 169 assigned category at time 3474.2640136137575
# Patient 175 arrived by ambulance at time 3474.2640136137575.
# Patient 175 is a traum patient, cannot be diverted.
# Patient 175 moved to Zone 1R at time 3474.2640136137575.
# Patient 84 moved to Waiting Room at time 3486.0597833523593. Number of people in the waiting room: 27
# Patient 84 moved to Zone 4 at time 3486.0597833523593. Number of people in the waiting room: 26
# Patient 84 spent 67.09057169674855 minutes in Zone 4.
# Patient 84 discharged at time 3553.150355049108.
# Patient 84 arrived as walk-in (['Urgent']) at time 83
# Patient 84 assigned category at time 83
# Patient 86 moved to Waiting Room at time 3563.9487357938206. Number of people in the waiting room: 27
# Patient 86 moved to Zone 3 at time 3563.9487357938206. Number of people in the waiting room: 26
# Patient 86 spent 21.080856420797375 minutes in Zone 3.
# Patient 86 discharged at time 3585.029592214618.
# Patient 86 arrived as walk-in (['Referred']) at time 85
# Patient 86 assigned category at time 85
# Patient 88 moved to Waiting Room at time 3598.5985432682055. Number of people in the waiting room: 27
# Patient 88 moved to Zone 4 at time 3598.5985432682055. Number of people in the waiting room: 26
# Patient 175 spent 136.96093395444916 minutes in Zone 1R.
# Patient 175 discharged at time 3611.2249475682065.
# Patient 175 assigned category at time 3611.2249475682065
# Patient 179 arrived by ambulance at time 3611.2249475682065.
# Patient 179 is a traum patient, cannot be diverted.
# Patient 179 moved to Zone 1R at time 3611.2249475682065.
# Patient 88 spent 79.22252383796666 minutes in Zone 4.
# Patient 88 discharged at time 3677.821067106172.
# Patient 88 arrived as walk-in (['Non-Urgent']) at time 87
# Patient 88 assigned category at time 87
# Patient 91 moved to Waiting Room at time 3688.7302432125293. Number of people in the waiting room: 27
# Patient 91 moved to Zone 3 at time 3688.7302432125293. Number of people in the waiting room: 26
# Patient 179 spent 105.47312239025676 minutes in Zone 1R.
# Patient 179 discharged at time 3716.6980699584633.
# Patient 179 assigned category at time 3716.6980699584633
# Patient 182 arrived by ambulance at time 3716.6980699584633.
# Patient 182 is a traum patient, cannot be diverted.
# Patient 182 moved to Zone 1R at time 3716.6980699584633.
# Patient 91 spent 45.390244066364616 minutes in Zone 3.
# Patient 91 discharged at time 3734.120487278894.
# Patient 91 arrived as walk-in (['Non-Urgent']) at time 90
# Patient 91 assigned category at time 90
# Patient 92 moved to Waiting Room at time 3746.0551668320268. Number of people in the waiting room: 27
# Patient 92 moved to Zone 3 at time 3746.0551668320268. Number of people in the waiting room: 26
# Patient 92 spent 50.451459486395734 minutes in Zone 3.
# Patient 92 discharged at time 3796.5066263184226.
# Patient 92 arrived as walk-in (['Urgent']) at time 91
# Patient 92 assigned category at time 91
# Patient 93 moved to Waiting Room at time 3807.652898412426. Number of people in the waiting room: 27
# Patient 93 moved to Zone 3 at time 3807.652898412426. Number of people in the waiting room: 26
# Patient 182 spent 170.73389068585374 minutes in Zone 1R.
# Patient 182 discharged at time 3887.431960644317.
# Patient 182 assigned category at time 3887.431960644317
# Patient 195 arrived by ambulance at time 3887.431960644317.
# Patient 195 is a traum patient, cannot be diverted.
# Patient 195 moved to Zone 1R at time 3887.431960644317.
# Patient 93 spent 85.81388861150067 minutes in Zone 3.
# Patient 93 discharged at time 3893.466787023927.
# Patient 93 arrived as walk-in (['Referred']) at time 92
# Patient 93 assigned category at time 92
# Patient 94 moved to Waiting Room at time 3906.623708108579. Number of people in the waiting room: 27
# Patient 94 moved to Zone 4 at time 3906.623708108579. Number of people in the waiting room: 26
# Patient 94 spent 57.53262895292142 minutes in Zone 4.
# Patient 94 discharged at time 3964.156337061501.
# Patient 94 arrived as walk-in (['Urgent']) at time 93
# Patient 94 assigned category at time 93
# Patient 95 moved to Waiting Room at time 3978.0399813955014. Number of people in the waiting room: 27
# Patient 95 moved to Zone 4 at time 3978.0399813955014. Number of people in the waiting room: 26
# Patient 95 spent 41.49960457463747 minutes in Zone 4.
# Patient 95 discharged at time 4019.539585970139.
# Patient 95 arrived as walk-in (['Non-Urgent']) at time 94
# Patient 95 assigned category at time 94
# Patient 97 moved to Waiting Room at time 4034.1628041625195. Number of people in the waiting room: 27
# Patient 97 moved to Zone 3 at time 4034.1628041625195. Number of people in the waiting room: 26
# Patient 195 spent 164.7104251491603 minutes in Zone 1R.
# Patient 195 discharged at time 4052.142385793477.
# Patient 195 assigned category at time 4052.142385793477
# Patient 197 arrived by ambulance at time 4052.142385793477.
# Patient 197 categorized as Non-Trauma.
# Patient 197 labelled as Non-Urgent.
# Patient 97 spent 29.348047858140283 minutes in Zone 3.
# Patient 97 discharged at time 4063.51085202066.
# Patient 97 arrived as walk-in (['Non-Urgent']) at time 96
# Patient 97 assigned category at time 96
# Patient 197 moved to Waiting Room at time 4065.143526035902. Number of people in the waiting room: 27
# Patient 197 assigned category at time 4065.143526035902
# Patient 198 arrived by ambulance at time 4065.143526035902.
# Patient 198 categorized as Non-Trauma.
# Patient 198 labelled as Non-Urgent.
# Patient 99 moved to Waiting Room at time 4074.334191714869. Number of people in the waiting room: 28
# Patient 99 moved to Zone 3 at time 4074.334191714869. Number of people in the waiting room: 27
# Patient 198 moved to Waiting Room at time 4075.718339945547. Number of people in the waiting room: 28
# Patient 198 assigned category at time 4075.718339945547
# Patient 199 arrived by ambulance at time 4075.718339945547.
# Patient 199 is a traum patient, cannot be diverted.
# Patient 199 moved to Zone 1R at time 4075.718339945547.
# Patient 99 spent 74.0563431534459 minutes in Zone 3.
# Patient 99 discharged at time 4148.390534868315.
# Patient 99 arrived as walk-in (['Urgent']) at time 98
# Patient 99 assigned category at time 98
# Patient 199 spent 81.08800714100684 minutes in Zone 1R.
# Patient 199 discharged at time 4156.806347086554.
# Patient 199 assigned category at time 4156.806347086554
# Patient 202 arrived by ambulance at time 4156.806347086554.
# Patient 202 is a traum patient, cannot be diverted.
# Patient 202 moved to Zone 1R at time 4156.806347086554.
# Patient 100 moved to Waiting Room at time 4161.555947054189. Number of people in the waiting room: 29
# Patient 100 moved to Zone 3 at time 4161.555947054189. Number of people in the waiting room: 28
# Patient 100 spent 51.99126858398053 minutes in Zone 3.
# Patient 100 discharged at time 4213.54721563817.
# Patient 100 arrived as walk-in (['Non-Urgent']) at time 99
# Patient 100 assigned category at time 99
# Patient 101 moved to Waiting Room at time 4225.333715925541. Number of people in the waiting room: 29
# Patient 101 moved to Zone 3 at time 4225.333715925541. Number of people in the waiting room: 28
# Patient 101 spent 55.19725577788306 minutes in Zone 3.
# Patient 101 discharged at time 4280.530971703423.
# Patient 101 arrived as walk-in (['Non-Urgent']) at time 100
# Patient 101 assigned category at time 100
# Patient 104 moved to Waiting Room at time 4291.009455095541. Number of people in the waiting room: 29
# Patient 104 moved to Zone 3 at time 4291.009455095541. Number of people in the waiting room: 28
# Patient 202 spent 163.05428795817468 minutes in Zone 1R.
# Patient 202 discharged at time 4319.860635044728.
# Patient 202 assigned category at time 4319.860635044728
# Patient 204 arrived by ambulance at time 4319.860635044728.
# Patient 204 is a traum patient, cannot be diverted.
# Patient 204 moved to Zone 1R at time 4319.860635044728.
# Patient 104 spent 67.95908442968663 minutes in Zone 3.
# Patient 104 discharged at time 4358.968539525227.
# Patient 104 arrived as walk-in (['Urgent']) at time 103
# Patient 104 assigned category at time 103
# Patient 105 moved to Waiting Room at time 4370.291341626655. Number of people in the waiting room: 29
# Patient 105 moved to Zone 3 at time 4370.291341626655. Number of people in the waiting room: 28
# Patient 105 spent 57.55807523436291 minutes in Zone 3.
# Patient 105 discharged at time 4427.849416861018.
# Patient 105 arrived as walk-in (['Non-Urgent']) at time 104
# Patient 105 assigned category at time 104
# Patient 106 moved to Waiting Room at time 4439.44081974009. Number of people in the waiting room: 29
# Patient 106 moved to Zone 4 at time 4439.44081974009. Number of people in the waiting room: 28
# Patient 204 spent 122.39886003297403 minutes in Zone 1R.
# Patient 204 discharged at time 4442.259495077702.
# Patient 204 assigned category at time 4442.259495077702
# Patient 207 arrived by ambulance at time 4442.259495077702.
# Patient 207 categorized as Non-Trauma.
# Patient 207 labelled as Non-Urgent.
# Patient 207 moved to Waiting Room at time 4454.304987415551. Number of people in the waiting room: 29
# Patient 207 assigned category at time 4454.304987415551
# Patient 220 arrived by ambulance at time 4454.304987415551.
# Patient 220 is a traum patient, cannot be diverted.
# Patient 220 moved to Zone 1R at time 4454.304987415551.
# Patient 106 spent 39.46213948530597 minutes in Zone 4.
# Patient 106 discharged at time 4478.9029592253955.
# Patient 106 arrived as walk-in (['Referred']) at time 105
# Patient 106 assigned category at time 105
# Patient 107 moved to Waiting Room at time 4491.0769215252085. Number of people in the waiting room: 30
# Patient 107 moved to Zone 3 at time 4491.0769215252085. Number of people in the waiting room: 29
# Patient 220 spent 64.68832655471175 minutes in Zone 1R.
# Patient 220 discharged at time 4518.993313970263.
# Patient 220 assigned category at time 4518.993313970263
# Patient 221 arrived by ambulance at time 4518.993313970263.
# Patient 221 is a traum patient, cannot be diverted.
# Patient 221 moved to Zone 1R at time 4518.993313970263.
# Patient 107 spent 60.35963272956871 minutes in Zone 3.
# ...
# Patient 484 is a traum patient, cannot be diverted.
# Patient 484 moved to Zone 1R at time 8668.787813232771.
# Patient 189 spent 28.083372213837357 minutes in Zone 4.
# Patient 189 discharged at time 8669.574760645983.
# Patient 189 arrived as walk-in (['Non-Urgent']) at time 188
# Patient 189 assigned category at time 188
# Patient 190 moved to Waiting Room at time 8683.634132753536. Number of people in the waiting room: 65
# Patient 190 moved to Zone 3 at time 8683.634132753536. Number of people in the waiting room: 64
# Patient 190 spent 47.41235108706771 minutes in Zone 3.
# Patient 190 discharged at time 8731.046483840604.
# Patient 190 arrived as walk-in (['Referred']) at time 189
# Patient 190 assigned category at time 189
# Patient 191 moved to Waiting Room at time 8744.23338339488. Number of people in the waiting room: 65
# Patient 191 moved to Zone 4 at time 8744.23338339488. Number of people in the waiting room: 64
# Patient 484 spent 76.77514128404572 minutes in Zone 1R.
# Patient 484 discharged at time 8745.562954516818.
# Patient 484 assigned category at time 8745.562954516818
# Patient 485 arrived by ambulance at time 8745.562954516818.
# Patient 485 is a traum patient, cannot be diverted.
# Patient 485 moved to Zone 1R at time 8745.562954516818.
# Patient 191 spent 55.931190458130494 minutes in Zone 4.
# Patient 191 discharged at time 8800.16457385301.
# Patient 191 arrived as walk-in (['Urgent']) at time 190
# Patient 191 assigned category at time 190
# Patient 192 moved to Waiting Room at time 8814.58231891628. Number of people in the waiting room: 65
# Patient 192 moved to Zone 4 at time 8814.58231891628. Number of people in the waiting room: 64
# Patient 485 spent 126.47742234004191 minutes in Zone 1R.
# Patient 485 discharged at time 8872.04037685686.
# Patient 485 assigned category at time 8872.04037685686
# Patient 489 arrived by ambulance at time 8872.04037685686.
# Patient 489 categorized as Non-Trauma.
# Patient 489 labelled as Non-Urgent.
# Patient 489 moved to Waiting Room at time 8884.409744182829. Number of people in the waiting room: 65
# Patient 489 assigned category at time 8884.409744182829
# Patient 490 arrived by ambulance at time 8884.409744182829.
# Patient 490 categorized as Non-Trauma.
# Patient 490 labelled as Non-Urgent.
# Patient 192 spent 77.08280051558881 minutes in Zone 4.
# Patient 192 discharged at time 8891.66511943187.
# Patient 192 arrived as walk-in (['Non-Urgent']) at time 191
# Patient 192 assigned category at time 191
# Patient 490 moved to Waiting Room at time 8895.458336300511. Number of people in the waiting room: 66
# Patient 490 assigned category at time 8895.458336300511
# Patient 492 arrived by ambulance at time 8895.458336300511.
# Patient 492 categorized as Non-Trauma.
# Patient 492 labelled as Non-Urgent.
# Patient 193 moved to Waiting Room at time 8906.226915522642. Number of people in the waiting room: 67
# Patient 193 moved to Zone 3 at time 8906.226915522642. Number of people in the waiting room: 66
# Patient 492 moved to Waiting Room at time 8906.23468624726. Number of people in the waiting room: 67
# Patient 492 assigned category at time 8906.23468624726
# Patient 493 arrived by ambulance at time 8906.23468624726.
# Patient 493 is a traum patient, cannot be diverted.
# Patient 493 moved to Zone 1R at time 8906.23468624726.
# Patient 193 spent 50.81175046022314 minutes in Zone 3.
# Patient 193 discharged at time 8957.038665982865.
# Patient 193 arrived as walk-in (['Non-Urgent']) at time 192
# Patient 193 assigned category at time 192
# Patient 194 moved to Waiting Room at time 8971.45408429531. Number of people in the waiting room: 68
# Patient 194 moved to Zone 3 at time 8971.45408429531. Number of people in the waiting room: 67
# Patient 194 spent 54.350793149109734 minutes in Zone 3.
# Patient 194 discharged at time 9025.80487744442.
# Patient 194 arrived as walk-in (['Urgent']) at time 193
# Patient 194 assigned category at time 193
# Patient 196 moved to Waiting Room at time 9037.209462338607. Number of people in the waiting room: 68
# Patient 196 moved to Zone 4 at time 9037.209462338607. Number of people in the waiting room: 67
# Patient 196 spent 22.748644836382226 minutes in Zone 4.
# Patient 196 discharged at time 9059.958107174989.
# Patient 196 arrived as walk-in (['Urgent']) at time 195
# Patient 196 assigned category at time 195
# Patient 200 moved to Waiting Room at time 9073.719792270673. Number of people in the waiting room: 68
# Patient 200 moved to Zone 4 at time 9073.719792270673. Number of people in the waiting room: 67
# Patient 493 spent 169.23966357077313 minutes in Zone 1R.
# Patient 493 discharged at time 9075.474349818034.
# Patient 493 assigned category at time 9075.474349818034
# Patient 494 arrived by ambulance at time 9075.474349818034.
# Patient 494 is a traum patient, cannot be diverted.
# Patient 494 moved to Zone 1R at time 9075.474349818034.
# Patient 200 spent 42.97676829008688 minutes in Zone 4.
# Patient 200 discharged at time 9116.69656056076.
# Patient 200 arrived as walk-in (['Urgent']) at time 199
# Patient 200 assigned category at time 199
# Patient 201 moved to Waiting Room at time 9127.81827871982. Number of people in the waiting room: 68
# Patient 201 moved to Zone 4 at time 9127.81827871982. Number of people in the waiting room: 67
# Patient 201 spent 27.677272124170827 minutes in Zone 4.
# Patient 201 discharged at time 9155.49555084399.
# Patient 201 arrived as walk-in (['Urgent']) at time 200
# Patient 201 assigned category at time 200
# Patient 203 moved to Waiting Room at time 9168.11295605836. Number of people in the waiting room: 68
# Patient 203 moved to Zone 4 at time 9168.11295605836. Number of people in the waiting room: 67
# Patient 494 spent 112.69857840903066 minutes in Zone 1R.
# Patient 494 discharged at time 9188.172928227064.
# Patient 494 assigned category at time 9188.172928227064
# Patient 497 arrived by ambulance at time 9188.172928227064.
# Patient 497 is a traum patient, cannot be diverted.
# Patient 497 moved to Zone 1R at time 9188.172928227064.
# Patient 497 spent 57.7429706615303 minutes in Zone 1R.
# Patient 497 discharged at time 9245.915898888594.
# Patient 497 assigned category at time 9245.915898888594
# Patient 499 arrived by ambulance at time 9245.915898888594.
# Patient 499 is a traum patient, cannot be diverted.
# Patient 499 moved to Zone 1R at time 9245.915898888594.
# Patient 203 spent 85.22592244817899 minutes in Zone 4.
# Patient 203 discharged at time 9253.338878506538.
# Patient 203 arrived as walk-in (['Urgent']) at time 202
# Patient 203 assigned category at time 202
# Patient 205 moved to Waiting Room at time 9266.468718133023. Number of people in the waiting room: 68
# Patient 205 moved to Zone 4 at time 9266.468718133023. Number of people in the waiting room: 67
# Patient 499 spent 55.331251435916286 minutes in Zone 1R.
# Patient 499 discharged at time 9301.24715032451.
# Patient 499 assigned category at time 9301.24715032451
# Patient 501 arrived by ambulance at time 9301.24715032451.
# Patient 501 categorized as Non-Trauma.
# Patient 501 labelled as Non-Urgent.
# Patient 501 moved to Waiting Room at time 9315.219281459233. Number of people in the waiting room: 68
# Patient 501 assigned category at time 9315.219281459233
# Patient 509 arrived by ambulance at time 9315.219281459233.
# Patient 509 is a traum patient, cannot be diverted.
# Patient 509 moved to Zone 1R at time 9315.219281459233.
# Patient 205 spent 62.03431507159274 minutes in Zone 4.
# Patient 205 discharged at time 9328.503033204615.
# Patient 205 arrived as walk-in (['Non-Urgent']) at time 204
# Patient 205 assigned category at time 204
# Patient 206 moved to Waiting Room at time 9338.928433833327. Number of people in the waiting room: 69
# Patient 206 moved to Zone 3 at time 9338.928433833327. Number of people in the waiting room: 68
# Patient 509 spent 60.335200790809154 minutes in Zone 1R.
# Patient 509 discharged at time 9375.554482250041.
# Patient 509 assigned category at time 9375.554482250041
# Patient 512 arrived by ambulance at time 9375.554482250041.
# Patient 512 categorized as Non-Trauma.
# Patient 512 labelled as Non-Urgent.
# Patient 512 moved to Waiting Room at time 9390.513289129625. Number of people in the waiting room: 69
# Patient 512 assigned category at time 9390.513289129625
# Patient 513 arrived by ambulance at time 9390.513289129625.
# Patient 513 categorized as Non-Trauma.
# Patient 513 labelled as Non-Urgent.
# Patient 206 spent 64.80068757204796 minutes in Zone 3.
# Patient 206 discharged at time 9403.729121405375.
# Patient 206 arrived as walk-in (['Non-Urgent']) at time 205
# Patient 206 assigned category at time 205
# Patient 513 moved to Waiting Room at time 9405.195030811934. Number of people in the waiting room: 70
# Patient 513 assigned category at time 9405.195030811934
# Patient 520 arrived by ambulance at time 9405.195030811934.
# Patient 520 categorized as Non-Trauma.
# Patient 520 labelled as Non-Urgent.
# Patient 208 moved to Waiting Room at time 9415.755261295975. Number of people in the waiting room: 71
# Patient 208 moved to Zone 4 at time 9415.755261295975. Number of people in the waiting room: 70
# Patient 520 moved to Waiting Room at time 9415.918489748208. Number of people in the waiting room: 71
# Patient 520 assigned category at time 9415.918489748208
# Patient 523 arrived by ambulance at time 9415.918489748208.
# Patient 523 is a traum patient, cannot be diverted.
# Patient 523 moved to Zone 1R at time 9415.918489748208.
# Patient 208 spent 40.97112658257078 minutes in Zone 4.
# Patient 208 discharged at time 9456.726387878545.
# Patient 208 arrived as walk-in (['Urgent']) at time 207
# Patient 208 assigned category at time 207
# Patient 209 moved to Waiting Room at time 9467.09753308346. Number of people in the waiting room: 72
# Patient 209 moved to Zone 3 at time 9467.09753308346. Number of people in the waiting room: 71
# Patient 523 spent 103.9015344051816 minutes in Zone 1R.
# Patient 523 discharged at time 9519.82002415339.
# Patient 523 assigned category at time 9519.82002415339
# Patient 525 arrived by ambulance at time 9519.82002415339.
# Patient 525 is a traum patient, cannot be diverted.
# Patient 525 moved to Zone 1R at time 9519.82002415339.
# Patient 209 spent 58.81259408067665 minutes in Zone 3.
# Patient 209 discharged at time 9525.910127164138.
# Patient 209 arrived as walk-in (['Non-Urgent']) at time 208
# Patient 209 assigned category at time 208
# Patient 210 moved to Waiting Room at time 9537.830672170281. Number of people in the waiting room: 72
# Patient 210 moved to Zone 4 at time 9537.830672170281. Number of people in the waiting room: 71
# Patient 210 spent 27.452099989500923 minutes in Zone 4.
# Patient 210 discharged at time 9565.282772159782.
# Patient 210 arrived as walk-in (['Non-Urgent']) at time 209
# Patient 210 assigned category at time 209
# Patient 211 moved to Waiting Room at time 9578.813011122742. Number of people in the waiting room: 72
# Patient 211 moved to Zone 4 at time 9578.813011122742. Number of people in the waiting room: 71
# Patient 525 spent 98.31322191809102 minutes in Zone 1R.
# Patient 525 discharged at time 9618.133246071482.
# Patient 525 assigned category at time 9618.133246071482
# Patient 527 arrived by ambulance at time 9618.133246071482.
# Patient 527 is a traum patient, cannot be diverted.
# Patient 527 moved to Zone 1R at time 9618.133246071482.
# Patient 211 spent 73.00826161479546 minutes in Zone 4.
# Patient 211 discharged at time 9651.821272737538.
# Patient 211 arrived as walk-in (['Referred']) at time 210
# Patient 211 assigned category at time 210
# Patient 212 moved to Waiting Room at time 9664.108311038903. Number of people in the waiting room: 72
# Patient 212 moved to Zone 3 at time 9664.108311038903. Number of people in the waiting room: 71
# Patient 212 spent 65.18164017077376 minutes in Zone 3.
# Patient 212 discharged at time 9729.289951209676.
# Patient 212 arrived as walk-in (['Urgent']) at time 211
# Patient 212 assigned category at time 211
# Patient 213 moved to Waiting Room at time 9743.821439261643. Number of people in the waiting room: 72
# Patient 213 moved to Zone 4 at time 9743.821439261643. Number of people in the waiting room: 71
# Patient 527 spent 136.26268458331123 minutes in Zone 1R.
# Patient 527 discharged at time 9754.395930654793.
# Patient 527 assigned category at time 9754.395930654793
# Patient 533 arrived by ambulance at time 9754.395930654793.
# Patient 533 is a traum patient, cannot be diverted.
# Patient 533 moved to Zone 1R at time 9754.395930654793.
# Patient 213 spent 39.11147851838748 minutes in Zone 4.
# Patient 213 discharged at time 9782.93291778003.
# Patient 213 arrived as walk-in (['Non-Urgent']) at time 212
# Patient 213 assigned category at time 212
# Patient 214 moved to Waiting Room at time 9794.888448964899. Number of people in the waiting room: 72
# Patient 214 moved to Zone 4 at time 9794.888448964899. Number of people in the waiting room: 71
# Patient 533 spent 52.85978164074454 minutes in Zone 1R.
# Patient 533 discharged at time 9807.255712295537.
# Patient 533 assigned category at time 9807.255712295537
# Patient 535 arrived by ambulance at time 9807.255712295537.
# Patient 535 is a traum patient, cannot be diverted.
# Patient 535 moved to Zone 1R at time 9807.255712295537.
# Patient 214 spent 27.25331006984046 minutes in Zone 4.
# Patient 214 discharged at time 9822.14175903474.
# Patient 214 arrived as walk-in (['Non-Urgent']) at time 213
# Patient 214 assigned category at time 213
# Patient 215 moved to Waiting Room at time 9835.754592915542. Number of people in the waiting room: 72
# Patient 215 moved to Zone 4 at time 9835.754592915542. Number of people in the waiting room: 71
# Patient 535 spent 64.70286579749822 minutes in Zone 1R.
# Patient 535 discharged at time 9871.958578093036.
# Patient 535 assigned category at time 9871.958578093036
# Patient 536 arrived by ambulance at time 9871.958578093036.
# Patient 536 is a traum patient, cannot be diverted.
# Patient 536 moved to Zone 1R at time 9871.958578093036.
# Patient 215 spent 41.28289739235023 minutes in Zone 4.
# Patient 215 discharged at time 9877.037490307892.
# Patient 215 arrived as walk-in (['Referred']) at time 214
# Patient 215 assigned category at time 214
# Patient 216 moved to Waiting Room at time 9887.242893936402. Number of people in the waiting room: 72
# Patient 216 moved to Zone 3 at time 9887.242893936402. Number of people in the waiting room: 71
# Patient 216 spent 43.8839789333038 minutes in Zone 3.
# Patient 216 discharged at time 9931.126872869705.
# Patient 216 arrived as walk-in (['Urgent']) at time 215
# Patient 216 assigned category at time 215
# Patient 217 moved to Waiting Room at time 9946.05705229942. Number of people in the waiting room: 72
# Patient 217 moved to Zone 4 at time 9946.05705229942. Number of people in the waiting room: 71
# Patient 536 spent 125.06782462502274 minutes in Zone 1R.
# Patient 536 discharged at time 9997.026402718058.
# Patient 536 assigned category at time 9997.026402718058
# Patient 538 arrived by ambulance at time 9997.026402718058.
# Patient 538 categorized as Non-Trauma.
# Patient 538 labelled as Non-Urgent.
# Patient 538 moved to Waiting Room at time 10011.27817893386. Number of people in the waiting room: 72
# Patient 538 assigned category at time 10011.27817893386
# Patient 539 arrived by ambulance at time 10011.27817893386.
# Patient 539 is a traum patient, cannot be diverted.
# Patient 539 moved to Zone 1R at time 10011.27817893386.
# Patient 217 spent 80.73814116988429 minutes in Zone 4.
# Patient 217 discharged at time 10026.795193469305.
# Patient 217 arrived as walk-in (['Non-Urgent']) at time 216
# Patient 217 assigned category at time 216
# Patient 218 moved to Waiting Room at time 10038.807314521326. Number of people in the waiting room: 73
# Patient 218 moved to Zone 4 at time 10038.807314521326. Number of people in the waiting room: 72
# Patient 218 spent 20.201289586513752 minutes in Zone 4.
# Patient 218 discharged at time 10059.00860410784.
# Patient 218 arrived as walk-in (['Non-Urgent']) at time 217
# Patient 218 assigned category at time 217
# Patient 219 moved to Waiting Room at time 10070.257397399964. Number of people in the waiting room: 73
# Patient 219 moved to Zone 3 at time 10070.257397399964. Number of people in the waiting room: 72
